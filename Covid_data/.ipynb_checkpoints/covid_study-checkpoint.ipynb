# %%
import pandas as pd
import matplotlib.pyplot as pt
import seaborn as sns

# %%
url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv"

# %% [markdown]
# # Reading Raw Data

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#     Province/State         Country/Region        Lat       Long  1/22/20  \
# 0              NaN            Afghanistan  33.000000  65.000000        0
# 1              NaN                Albania  41.153300  20.168300        0
# 2              NaN                Algeria  28.033900   1.659600        0
# 3              NaN                Andorra  42.506300   1.521800        0
# 4              NaN                 Angola -11.202700  17.873900        0
# ..             ...                    ...        ...        ...      ...
# 261            NaN  Sao Tome and Principe   0.186360   6.613081        0
# 262            NaN                  Yemen  15.552727  48.516388        0
# 263            NaN                Comoros -11.645500  43.333300        0
# 264            NaN             Tajikistan  38.861034  71.276093        0
# 265            NaN                Lesotho -29.609988  28.233608        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  5/26/20  5/27/20  \
# 0          0        0        0        0        0  ...    11831    12456
# 1          0        0        0        0        0  ...     1029     1050
# 2          0        0        0        0        0  ...     8697     8857
# 3          0        0        0        0        0  ...      763      763
# 4          0        0        0        0        0  ...       70       71
# ..       ...      ...      ...      ...      ...  ...      ...      ...
# 261        0        0        0        0        0  ...      441      443
# 262        0        0        0        0        0  ...      249      256
# 263        0        0        0        0        0  ...       87       87
# 264        0        0        0        0        0  ...     3266     3424
# 265        0        0        0        0        0  ...        2        2
#
#      5/28/20  5/29/20  5/30/20  5/31/20  6/1/20  6/2/20  6/3/20  6/4/20
# 0      13036    13659    14525    15205   15750   16509   17267   18054
# 1       1076     1099     1122     1137    1143    1164    1184    1197
# 2       8997     9134     9267     9394    9513    9626    9733    9831
# 3        763      764      764      764     765     844     851     852
# 4         74       81       84       86      86      86      86      86
# ..       ...      ...      ...      ...     ...     ...     ...     ...
# 261      458      463      479      483     484     484     484     485
# 262      278      283      310      323     354     399     419     453
# 263       87       87      106      106     106     132     132     132
# 264     3563     3686     3807     3930    4013    4100    4191    4289
# 265        2        2        2        2       2       2       4       4
#
# [266 rows x 139 columns]

# %%
df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  5/26/20  5/27/20  5/28/20  5/29/20  \
# 0        0        0        0  ...    11831    12456    13036    13659
# 1        0        0        0  ...     1029     1050     1076     1099
# 2        0        0        0  ...     8697     8857     8997     9134
# 3        0        0        0  ...      763      763      763      764
# 4        0        0        0  ...       70       71       74       81
#
#    5/30/20  5/31/20  6/1/20  6/2/20  6/3/20  6/4/20
# 0    14525    15205   15750   16509   17267   18054
# 1     1122     1137    1143    1164    1184    1197
# 2     9267     9394    9513    9626    9733    9831
# 3      764      764     765     844     851     852
# 4       84       86      86      86      86      86
#
# [5 rows x 139 columns]

# %% [markdown]
# # Selecting Required Columns

# %%
drop_cols = ['Province/State','Lat','Long']

# %%
req_cols = [x for x in df.columns if x not in drop_cols]

# %%
df_new = df.loc[:,req_cols]

# %%
df_new
# Out:
#             Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0              Afghanistan        0        0        0        0        0
# 1                  Albania        0        0        0        0        0
# 2                  Algeria        0        0        0        0        0
# 3                  Andorra        0        0        0        0        0
# 4                   Angola        0        0        0        0        0
# ..                     ...      ...      ...      ...      ...      ...
# 261  Sao Tome and Principe        0        0        0        0        0
# 262                  Yemen        0        0        0        0        0
# 263                Comoros        0        0        0        0        0
# 264             Tajikistan        0        0        0        0        0
# 265                Lesotho        0        0        0        0        0
#
#      1/27/20  1/28/20  1/29/20  1/30/20  ...  5/26/20  5/27/20  5/28/20  \
# 0          0        0        0        0  ...    11831    12456    13036
# 1          0        0        0        0  ...     1029     1050     1076
# 2          0        0        0        0  ...     8697     8857     8997
# 3          0        0        0        0  ...      763      763      763
# 4          0        0        0        0  ...       70       71       74
# ..       ...      ...      ...      ...  ...      ...      ...      ...
# 261        0        0        0        0  ...      441      443      458
# 262        0        0        0        0  ...      249      256      278
# 263        0        0        0        0  ...       87       87       87
# 264        0        0        0        0  ...     3266     3424     3563
# 265        0        0        0        0  ...        2        2        2
#
#      5/29/20  5/30/20  5/31/20  6/1/20  6/2/20  6/3/20  6/4/20
# 0      13659    14525    15205   15750   16509   17267   18054
# 1       1099     1122     1137    1143    1164    1184    1197
# 2       9134     9267     9394    9513    9626    9733    9831
# 3        764      764      764     765     844     851     852
# 4         81       84       86      86      86      86      86
# ..       ...      ...      ...     ...     ...     ...     ...
# 261      463      479      483     484     484     484     485
# 262      283      310      323     354     399     419     453
# 263       87      106      106     106     132     132     132
# 264     3686     3807     3930    4013    4100    4191    4289
# 265        2        2        2       2       2       4       4
#
# [266 rows x 136 columns]

# %% [markdown]
# # Particular Country

# %%
country = 'China'

# %%
df_new['Country/Region']==country
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 261    False
# 262    False
# 263    False
# 264    False
# 265    False
# Name: Country/Region, Length: 266, dtype: bool

# %%
df_new.loc[df_new['Country/Region']==country]
# Out:
#    Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 49          China        1        9       15       39       60       70
# 50          China       14       22       36       41       68       80
# 51          China        6        9       27       57       75      110
# 52          China        1        5       10       18       35       59
# 53          China        0        2        2        4        7       14
# 54          China       26       32       53       78      111      151
# 55          China        2        5       23       23       36       46
# 56          China        1        3        3        4        5        7
# 57          China        4        5        8       19       22       33
# 58          China        1        1        2        8       13       18
# 59          China        0        2        4        9       15       21
# 60          China        5        5        9       32       83      128
# 61          China        0        2        2        5        8        8
# 62          China      444      444      549      761     1058     1423
# 63          China        4        9       24       43       69      100
# 64          China        0        0        1        7        7       11
# 65          China        1        5        9       18       33       47
# 66          China        2        7       18       18       36       72
# 67          China        0        1        3        4        4        6
# 68          China        2        3        4       17       21       27
# 69          China        1        2        2        2        5        6
# 70          China        1        1        2        3        4        7
# 71          China        0        0        0        1        1        6
# 72          China        0        3        5       15       22       35
# 73          China        2        6       15       27       46       75
# 74          China        9       16       20       33       40       53
# 75          China        1        1        1        6        9       13
# 76          China        5        8       15       28       44       69
# 77          China        4        4        8       10       14       23
# 78          China        0        0        0        0        0        0
# 79          China        0        2        2        3        4        5
# 80          China        1        2        5       11       16       26
# 81          China       10       27       43       62      104      128
#
#     1/28/20  1/29/20  1/30/20  ...  5/26/20  5/27/20  5/28/20  5/29/20  \
# 49      106      152      200  ...      991      991      991      991
# 50       91      111      114  ...      593      593      593      593
# 51      132      147      182  ...      579      579      579      579
# 52       80       84      101  ...      357      358      358      358
# 53       19       24       26  ...      139      139      139      139
# 54      207      277      354  ...     1592     1592     1592     1593
# 55       51       58       78  ...      254      254      254      254
# 56        9        9       12  ...      147      147      147      147
# 57       40       43       46  ...      169      169      169      169
# 58       33       48       65  ...      328      328      328      328
# 59       33       38       44  ...      945      945      945      945
# 60      168      206      278  ...     1276     1276     1276     1276
# 61        8       10       10  ...     1065     1066     1066     1079
# 62     3554     3554     4903  ...    68135    68135    68135    68135
# 63      143      221      277  ...     1019     1019     1019     1019
# 64       15       16       19  ...      232      232      232      232
# 65       70       99      129  ...      653      653      653      653
# 66      109      109      162  ...      937      937      937      937
# 67        8        9       14  ...      155      155      155      155
# 68       34       39       41  ...      149      149      149      149
# 69        7        7        7  ...       45       45       45       45
# 70       11       12       17  ...       75       75       75       75
# 71        6        6        8  ...       18       18       18       18
# 72       46       56       63  ...      308      308      308      308
# 73       95      130      158  ...      788      788      788      790
# 74       66       96      112  ...      670      671      671      672
# 75       27       27       35  ...      198      198      198      198
# 76       90      108      142  ...      564      564      564      564
# 77       24       27       31  ...      192      192      192      192
# 78        0        0        1  ...        1        1        1        1
# 79       10       13       14  ...       76       76       76       76
# 80       44       55       70  ...      185      185      185      185
# 81      173      296      428  ...     1268     1268     1268     1268
#
#     5/30/20  5/31/20  6/1/20  6/2/20  6/3/20  6/4/20
# 49      991      991     991     991     991     991
# 50      593      593     593     593     594     594
# 51      579      579     579     579     579     579
# 52      358      358     358     358     358     358
# 53      139      139     139     139     139     139
# 54     1593     1595    1596    1597    1598    1598
# 55      254      254     254     254     254     254
# 56      147      147     147     147     147     147
# 57      169      169     169     169     169     169
# 58      328      328     328     328     328     328
# 59      945      945     945     945     947     947
# 60     1276     1276    1276    1276    1276    1276
# 61     1082     1084    1087    1093    1093    1099
# 62    68135    68135   68135   68135   68135   68135
# 63     1019     1019    1019    1019    1019    1019
# 64      232      235     235     235     235     235
# 65      653      653     653     653     653     653
# 66      937      937     937     937     932     932
# 67      155      155     155     155     155     155
# 68      149      149     149     149     149     149
# 69       45       45      45      45      45      45
# 70       75       75      75      75      75      75
# 71       18       18      18      18      18      18
# 72      308      308     309     309     309     309
# 73      792      792     792     792     792     792
# 74      672      672     673     673     673     677
# 75      198      198     198     198     198     198
# 76      564      575     577     577     577     578
# 77      192      192     192     192     192     192
# 78        1        1       1       1       1       1
# 79       76       76      76      76      76      76
# 80      185      185     185     185     185     185
# 81     1268     1268    1268    1268    1268    1268
#
# [33 rows x 136 columns]

# %%
df_india = df_new.loc[df_new['Country/Region']==country].drop('Country/Region', axis = 1).T

df_india.reset_index(inplace = True)

df_india.columns = ['Date','total_cases']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-131-82eaf68043fb> in <module>
#       3 df_india.reset_index(inplace = True)
#       4
# ----> 5 df_india.columns = ['Date','total_cases']
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5285         try:
#    5286             object.__getattribute__(self, name)
# -> 5287             return object.__setattr__(self, name, value)
#    5288         except AttributeError:
#    5289             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     659
#     660     def _set_axis(self, axis, labels) -> None:
# --> 661         self._data.set_axis(axis, labels)
#     662         self._clear_item_cache()
#     663
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     176         if new_len != old_len:
#     177             raise ValueError(
# --> 178                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     179                 f"values have {new_len} elements"
#     180             )
#
# ValueError: Length mismatch: Expected axis has 34 elements, new values have 2 elements

# %%
df_india
# Out:
#         Date  total_cases
# 0    1/22/20            0
# 1    1/23/20            0
# 2    1/24/20            0
# 3    1/25/20            0
# 4    1/26/20            0
# ..       ...          ...
# 130  5/31/20       190609
# 131   6/1/20       198370
# 132   6/2/20       207191
# 133   6/3/20       216824
# 134   6/4/20       226713
#
# [135 rows x 2 columns]

# %%
df_india['Date'] = pd.to_datetime(df_india['Date'])

# %%
df_india.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         135 non-null    datetime64[ns]
#  1   total_cases  135 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 2.2 KB

# %%
df_india.plot(kind = 'scatter', x = 'Date', y= 'total_cases')
pt.xticks(rotation = 30)
pt.title("For India")
pt.show()

# %% [markdown]
# # Function for Particular Country

# %%
def plot_for_country(country_name):
    dfc = df_new.loc[df_new['Country/Region']==country_name].drop('Country/Region', axis = 1).T
    dfc.reset_index(inplace = True)
    dfc.columns = ['Date','total_cases']
    dfc['Date'] = pd.to_datetime(dfc['Date'])
    dfc.plot(kind = 'scatter', x = 'Date', y= 'total_cases')
    pt.xticks(rotation = 30)
    pt.title(f"For {country_name}")
    pt.show()

# %%
plot_for_country("China")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-128-3e69ce31a5fe> in <module>
# ----> 1 plot_for_country("China")
#
# <ipython-input-119-4d604c5b7b94> in plot_for_country(country_name)
#       2     dfc = df_new.loc[df_new['Country/Region']==country_name].drop('Country/Region', axis = 1).T
#       3     dfc.reset_index(inplace = True)
# ----> 4     dfc.columns = ['Date','total_cases']
#       5     dfc['Date'] = pd.to_datetime(dfc['Date'])
#       6     dfc.plot(kind = 'scatter', x = 'Date', y= 'total_cases')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5285         try:
#    5286             object.__getattribute__(self, name)
# -> 5287             return object.__setattr__(self, name, value)
#    5288         except AttributeError:
#    5289             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     659
#     660     def _set_axis(self, axis, labels) -> None:
# --> 661         self._data.set_axis(axis, labels)
#     662         self._clear_item_cache()
#     663
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     176         if new_len != old_len:
#     177             raise ValueError(
# --> 178                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     179                 f"values have {new_len} elements"
#     180             )
#
# ValueError: Length mismatch: Expected axis has 34 elements, new values have 2 elements

# %%
# sns.lmplot(x = 'Date', y = 'total_cases', data = df_india)
